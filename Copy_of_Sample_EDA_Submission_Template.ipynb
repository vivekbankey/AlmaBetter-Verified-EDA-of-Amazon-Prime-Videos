# %% [markdown]
# # **Project Name**    - Amazon Prime TV Shows and Movies Analysis

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# This project conducts an exploratory data analysis (EDA) on the Amazon Prime Video dataset, focusing on content available in the United States. Using a dataset of over 9,800+ titles and 124,000+ cast and crew records, the analysis aims to uncover patterns in content distribution, genre popularity, content growth trends, and audience engagement.
#
# Python libraries such as Pandas were used for data cleaning and manipulation, while Matplotlib and Seaborn were used for data visualization. The raw datasets were preprocessed to handle missing values, normalize complex list-based fields like genres, and ensure correct data types for numerical analysis. Titles and credits data were merged using a unique title_id to enable enriched analysis.
#
# Key findings reveal that Movies dominate the platform by volume (around 78%), while TV Shows consistently achieve higher average IMDb ratings, indicating stronger audience engagement for serialized content. The platform experienced rapid content growth after 2015, reflecting Amazon’s aggressive expansion strategy. Mainstream genres such as Drama, Comedy, Action, and Thriller form the bulk of the library, while niche genres like Anime and Documentaries, though less common, show significantly higher user ratings.
#
# The analysis also highlights that mature content (TV-MA and R-rated) tends to receive better audience ratings, and that runtime has no strong correlation with content quality, emphasizing that storytelling quality matters more than duration. Overall, the project shows that Amazon Prime Video currently prioritizes content quantity over quality, and that shifting investment toward high-performing TV Shows, niche genres, and mature storytelling could improve user satisfaction and long-term platform growth.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# In today’s highly competitive streaming industry, Amazon Prime Video manages a rapidly growing content library consisting of thousands of Movies and TV Shows from diverse genres and regions. However, simply increasing the volume of content does not guarantee higher user engagement or long-term subscriber retention.
#
# The key challenge lies in the lack of data-driven visibility into how different types of content actually perform. Stakeholders face difficulty in answering critical business questions such as:
#
# Which genres are over-represented and which are under-utilized in the current catalog?
#
# Does a higher IMDb rating (content quality) reliably translate into greater audience engagement?
#
# Are Movies or TV Shows more effective at driving long-term viewer satisfaction?
#
# How has the balance between older (“classic”) content and newer releases evolved over time?
#
# Which production countries contribute the most to high-performing content?
#
# Without clear analytical insights, content acquisition and production decisions risk being based on intuition rather than evidence, leading to inefficient budget allocation, overinvestment in low-performing categories, and missed opportunities in high-potential genres and regions.
#
# This project addresses this challenge by applying exploratory data analysis (EDA) to Amazon Prime Video’s content and credits datasets to transform raw catalog data into actionable intelligence that supports smarter content strategy, improved audience engagement, and sustainable business growth

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Specifically, this analysis aims to:
#
# Identify High-Performing Content Categories
# Analyze genres, content types (Movies vs TV Shows), and age certifications to determine which categories deliver the highest audience satisfaction and should receive greater investment.
#
# Evaluate Content Quality vs Engagement
# Examine the relationship between IMDb/TMDB ratings and audience popularity to understand whether high-quality content truly drives higher engagement.
#
# Assess Library Composition and Growth Trends
# Study the balance between Movies and TV Shows and track content release trends over time to evaluate whether Amazon Prime’s current strategy prioritizes volume over value.
#
# Support Smarter Content Investment Decisions
# Use analytical insights to guide future content acquisition, licensing, and original production by minimizing spending on low-performing genres and maximizing returns from high-performing ones.
#
# Strengthen Global Market Positioning
# Evaluate production country diversity to assess international content reach and identify high-potential markets for geographic expansion.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## Setting Up Some Basic Display Settings

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 20)

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd

credits_path = "/content/drive/MyDrive/Amazon_EDA/credits.csv"
credits = pd.read_csv(credits_path)

# %%
titles_path = "/content/drive/MyDrive/Amazon_EDA/titles.csv"
titles = pd.read_csv(titles_path)

# %% [markdown]
# ### Dataset First View

# %%
#First Look of Title Dataset Top 5
titles.head()

# %%
# First Look Of Credits Dataset Top 5.
credits.head()

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
print(" TITLES DATASET")
print("Rows:", titles.shape[0])
print("Columns:", titles.shape[1])

print("\n CREDITS DATASET")
print("Rows:", credits.shape[0])
print("Columns:", credits.shape[1])

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
print("TITLES DATASET INFO")
titles.info()

print("\n CREDITS DATASET INFO")
credits.info()

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
print(" Duplicate rows in TITLES:", titles.duplicated().sum())
print(" Duplicate rows in CREDITS:", credits.duplicated().sum())

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
print(" Missing values in TITLES")
titles.isnull().sum().sort_values(ascending=False)

# %%
print("\n Missing values in CREDITS")
credits.isnull().sum().sort_values(ascending=False)

# %%
# Visualizing the missing values
import matplotlib.pyplot as plt

missing_counts = titles.isnull().sum()
missing_counts = missing_counts[missing_counts > 0]  # only columns with missing values

plt.figure(figsize=(10,5))
missing_counts.plot(kind="bar")
plt.title("Missing Values per Column (Titles Dataset)")
plt.ylabel("Count of Missing Values")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The dataset contains two files: titles (movies and TV shows metadata) and credits (cast and crew details). The titles dataset has around 9,800 records and 15 columns, while the credits dataset has over 1,24,000 records and 5 columns. Movies are more frequent than TV shows. Several columns such as age certification(6487), seasons(8514), IMDb score(1021), and TMDB popularity(547) contain missing values. The missing value visualizations showed that missing data is not random, with movies mostly missing seasons and older titles missing rating-related information. The credits dataset is comparatively cleaner with very few missing values.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
print(titles.columns)
print(credits.columns)

# %%
# Dataset Describe for title
print(titles.describe())

# %%
# Dataset Describe for credit
print(credits.describe())

# %% [markdown]
# ### Variables Description

# %% [markdown]
#  **Titles Dataset:**
# * **​id:** Unique identifier for the title (Key to join with Credits).
# * **​title:** Name of the Movie or TV Show.
# * **​type:** Category of content (Movie or Show).
# * **​description:** Brief synopsis/plot summary.
# * **​release_year:** The year the content was released.
# * **​age_certification:** Age rating (e.g., R, PG-13).
# * **​runtime:** Duration of the content in minutes.
# * **​genres:** List of genres the title belongs to (e.g., Drama, Comedy).
# * **​production_countries:** List of countries where it was produced.
# * **​seasons:** Number of seasons (for TV Shows only).
# * **​imdb_score / tmdb_score:** User ratings on IMDb and TMDB.
# * **​imdb_votes:** Number of votes cast on IMDb (indicates popularity).
# * **​tmdb_popularity:** Popularity metric calculated by TMDB.

# %% [markdown]
#  **Credits Dataset:**
# * **​person_id:** Unique identifier for the person (actor/director).
# * **​id:** Foreign key linking to the Titles dataset.
# * **​name:** Name of the actor or director.
# * **​character:** Name of the character played (for Actors).
# * **​role:** Role in the production (ACTOR or DIRECTOR).

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
print("--------------Title-------------")
print(titles.nunique())
print("-------------Credit----------------")
print(credits.nunique())

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
# 1. Handling Duplicates
# Dropping duplicates to ensure data integrity
titles.drop_duplicates(inplace=True)
credits.drop_duplicates(inplace=True)

# %%
# 2. Dropping Unnecessary column.
# (Dropping character column.),because we don't need character name, we need actor and director.
credits.drop('character', axis=1, inplace=True)

# %%
# 3. Handling Missing Values
# For Seasons : we gonna do 0 because incase of droping it system thinks it is not movie or tv serial.
titles['seasons'] = titles['seasons'].fillna(0) # Filling NA with 0.

# %%
# Filling Ratings/Votes with 0.
# So these variables also have many null values so we will fill it with 0.
# Logic: The Unrated content gets a 0 (neutral) Score because these consists of niche or new titles that haven't received enough votes to generate a score.
titles['imdb_score'] = titles['imdb_score'].fillna(0) # Filling NA with 0.
titles['imdb_votes'] = titles['imdb_votes'].fillna(0) # Filling NA with 0.
titles['tmdb_score'] = titles['tmdb_score'].fillna(0) # Filling NA with 0.
titles['tmdb_popularity'] = titles['tmdb_popularity'].fillna(0) # Filling NA with 0.

# %%
# Fill text columns with Placeholders.
# Logic: Keeping the data available for other analysis like (genres).

# Filling NA with 'Not Rated'.
titles['age_certification'] = titles['age_certification'].fillna('Not Rated')

# Filling NA with 'No Description'.
titles['description'] = titles['description'].fillna('No Description')

# %%
# 4. Converting Strings Lists to Actual Lists.
import ast # 'ast' helps us read text that looks like code (like "['Action', 'Drama']") and turn it into real code.

def clean_list_column(row):

    # Check if the value is a String (Text)
    # If it is NOT a string (like NaN or a number), we can't convert it.
    if isinstance(row, str) == False:
        return ['Unknown']

    # Try to convert the text into a List
    try:
        # literal_eval reads the string "['A', 'B']" and makes it a list ['A', 'B']
        result_list = ast.literal_eval(row)

        # Check if the list is empty
        # If the result is just [], it means we have no info.
        if len(result_list) == 0:
            return ['Unknown']

        # If it's not empty, return the good list!
        return result_list

    # Handle Errors
    # If the text was messy and couldn't be converted, return Unknown.
    except:
        return ['Unknown']

# Apply the cleaning function to genres and countries
titles['genres'] = titles['genres'].apply(clean_list_column)
titles['production_countries'] = titles['production_countries'].apply(clean_list_column)

# %%
titles.info()

# %%
credits.info()

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# 1. **​Handling Duplicates:** Removed duplicate rows from both datasets (titles and credits) to ensure unique records.
# 2. **Dropping Column:** I dropped this character from the Credits dataset because it had over 16,000 missing values and the specific role names are not required for our analysis of Actors and Directors.
#
# 3. **​Imputing Missing Values:**
#     * **​seasons:** Filled missing values with 0. This logically distinguishes Movies (0 seasons) from TV Shows (1+ seasons).
#     * **​age_certification:** Filled missing entries with "Not Rated" to preserve the data for analysis rather than deleting of the rows.
#     * **​Ratings:** Filled missing scores with 0 to handle unrated content.
# 4. **​Data Type Conversion:**
# * ​Converted genres and production_countries from strings to actual lists.
# * ​Handled Empty Lists: Replaced empty entries [] in production_countries with ['Unknown'] to prevent errors in future visualizations.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1------ Compare Movies vs TV Shows (Bar Chart).

# %%
# Chart - 1 visualization code
# Setting the fig size
plt.figure(figsize=(10, 6))

# Creating Count plot to compare Movies vs Shows.
ax = sns.countplot(x='type', data=titles, palette='viridis')

# Adding title And labels
plt.title('Movies vs. TV Shows Count')
plt.xlabel('Content Type', fontsize = 12)
plt.ylabel('Total Count Of Movies & TV Shows', fontsize = 12)

# Adding numbers (labels) on top of the bars
# 'ax.containers' is a list that holds all the bars we just drew on the chart.
for container in ax.containers:

    # 'bar_label' is a smart function that automatically finds the height of each bar and writes that number on top of it.
    ax.bar_label(container, padding=3, fontsize=12)

# Displaying the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  I use Bar Chart(Countplot) because it is the most effective way to compare the frequency of categorical variables. it provides an immediate visual comparison between the volume of Movies and TV Shows in the dataset

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Insights says that Movies(78%) is Dominating on amazon prime video over TV Shows(22%).
# Strategy :- Amazon Prime Video acquisition strategy has historically focused on building a massive films rather than TV shows.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Here The insights show that Amazon Prime has a heavy dominance of movies (78%) compared to TV shows (22%), which can limit long-term user engagement. Increasing the number of high-quality TV shows can improve customer retention and subscription duration. Missing rating data reduces recommendation accuracy and content performance evaluation. A low proportion of binge-worthy content and the presence of low-rated titles could negatively impact platform growth if not addressed. These insights help guide better content investment and strategy decisions.

# %% [markdown]
# #### Chart - 2 -----------Histogram

# %%
# Chart - 2 visualization code
# Seting up the figure size
plt.figure(figsize=(12, 6))

# filtering Out the Recent Content for better trend.
recent_content =titles[titles['release_year'] >= 2000]

# Creating histogram with Kde line.
sns.histplot(data=recent_content, x='release_year', kde=True, color='teal', bins=23)

# Adding title and labels
plt.title('Content Added by Release Year (2000 - 2022)', fontsize = 16)
plt.xlabel('Release Year', fontsize = 12)
plt.ylabel('Number Of Titles Available', fontsize = 12)

# Displaying the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I selected a Histogram & KDE (Kernel Density Estimate) line because it is most effective way to visualize how data is distributed over time. I wanted to see that Amazon Prime had old or New Modern type Movies.KDE line helps identify the smooth trend of growth.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Boom** :- I have seen that Amazon Prime has added much more movies from 2015 to 2021.
# **Focus** :- Amazon Prime Video has primary focus on New and Modern Movies from 2010.
# **2021-drop** :-There is an drop of movies in 2022,and i guess its not a stop in production, but likely because the dataset collection stopped early in that year, so the data for 2022 is incomplete.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, In creating a positive business impact.
#
# **​Marketing Strategy:** Since the data confirms that the library is very "modern," marketing teams should focus campaigns on "Fresh Content".
#
# **​Competitive Benchmarking:** The exponential growth curve shows that to stay competitive against giants like Netflix, needed to maintain this high rate of content acquisition. A slowdown now would look like a decline in service value to subscribers.

# %% [markdown]
# #### Chart - 3  (Bar Chart)------Top 10 Genre

# %%
# Chart - 3 visualization code
# .explode() the 'genres' column to count individual genres.
df_genres = titles.explode('genres') # .explode() converts each list-like element in a column into separate rows, repeating the index for each value.

# Calculating the value counts for the top 10 genres.
top_genres = df_genres['genres'].value_counts().head(10)

# Ploting Visualization (Bar Chart).
plt.figure(figsize=(12, 6))

# x = Genre Names (index), y = Counts (values).
ax = sns.barplot(x=top_genres.index, y=top_genres.values, palette='mako')

# Adding title and labels.
plt.title('Top 10 Genres on Amazon Prime Video', fontsize=16)
plt.xlabel('Genre of Movies & TV Shows', fontsize=12)
plt.ylabel('Number of Titles', fontsize=12)

# Rotating x-axis labels by 45 degrees so they don't overlap.
plt.xticks(rotation=45)

# Adding numbers(data labels) on top of the bars for clarity.
for container in ax.containers:
    ax.bar_label(container, padding=3)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  I wanted to identify the "Top 10" genres, this visualization allows for an instant comparison of volume. The descending order makes it easy to spot the dominant categories (Drama, Comedy) versus the niche ones (Family, European) at a glance.Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **​Drama is the Absolute Leader:** The chart clearly shows that Drama is the backbone of Amazon Prime's library with 4,762 titles, far outpacing any other genre.
#
# **The "Big Two":** There is a significant drop-off after the top two genres. Drama and Comedy (2,987) together make up a massive portion of the content, indicating that the platform prioritizes general entertainment over niche categories.
#
# **​Action & Thriller Presence:** Thriller (2,119) and Action (1,820) are strong contenders, showing that while Drama leads, there is still a healthy selection of high-intensity content.
#
# **Family Content is Lower:** Interestingly, Family content appears quite low on the list (9th place with 751 titles), suggesting the platform might be less focused on kids' programming compared to competitors like Disney+.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Impact:**
# The dominance of Drama and Comedy aligns well with broad audience preferences, which can drive higher watch time and subscriber retention.
#
# **Growth Opportunity:**
# Increasing investment in underrepresented genres like Romance and Action could help diversify the content library and tap into new audience segments.

# %% [markdown]
# #### Chart - 4  -------Bar Chart--------Top 10 Countries.
#
# ---

# %%
# Chart - 4 visualization code
# .explode() 'production_countries' because some titles are produced by multiple countries
# This will separates them so we can count each country individually.
df_countries = titles.explode('production_countries')

# Count the top 10 countries.
top_countries = df_countries[df_countries['production_countries'] != 'Unknown']['production_countries'].value_counts().head(10)

# Visualization (Bar Chart)
plt.figure(figsize=(12, 6))

# Creating the plot using the 'rocket' palette for a nice color gradient
ax = sns.barplot(x=top_countries.index, y=top_countries.values, palette='rocket')

# Adding title and labels
plt.title('Top 10 Production Countries on Amazon Prime', fontsize=16)
plt.xlabel('Country', fontsize=12)
plt.ylabel('Number of Titles', fontsize=12)

# Adding numbers on top of bars using the simple container method
for container in ax.containers:
    ax.bar_label(container, padding=3)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked a Bar Chart because I wanted to see where the movies and shows are actually coming from. It’s the best way to compare the total count of content produced by different countries. This chart helps me quickly spot if Amazon Prime is relying too much on one region, like the US.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **U.S. as the Global Content Hub**
# The strong lead of the United States suggests that it is the primary content producer for the platform. This reflects:
#
# A mature entertainment industry.
# High investment in digital streaming content.
# Strong demand from both domestic and international audiences
#
#
# **High Market Concentration Risk**
# Since most content comes from a single country, the platform is heavily dependent on U.S.-based productions. This creates a risk if:
# Production costs rise in the U.S.
#
# Regional regulations or strikes affect output
#
# Audience preferences shift toward local content
#
# **Downward Trend**
# Shows Fragmented Global Production
# The steep drop after the U.S. means no single country comes close in volume. This highlights:
#
# Limited production capacity or investment in other countries
#
# Untapped potential in international markets like India, South Korea, Japan, and Europe
#
# Strong Opportunity for Regional Expansion
# The platform can grow by:
#
# Investing in local-language content
#
# Partnering with regional studios
#
# Targeting fast-growing streaming markets (e.g., India, Southeast Asia, Latin America)

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Impact:**
# U.S. dominance ensures a steady supply of high-quality, globally appealing content.
#
# **Negative Risk:**[link text](https://)
# Over-reliance on one country reduces content diversity and may hurt growth in international markets.

# %% [markdown]
# #### Chart - 5 ------IMDB Score --------Boxplot.

# %%
# Chart - 5 visualization code
# Seting the figure size
plt.figure(figsize=(10, 6))

# Created a Box Plot
# This compares the 'spread' of scores for Movies vs TV Shows
# The line in the middle of the box is the Median score.
sns.boxplot(data=titles, x='type', y='imdb_score', palette='Set2')

# Adding title and labels
plt.title('Distribution of IMDb Scores: Movies vs. TV Shows', fontsize=16)
plt.xlabel('Content Type', fontsize=12)
plt.ylabel('IMDb Score', fontsize=12)

plt.show()

# %%
# Chart - 5 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I choose a Box Plot to analyze the distribution of IMDb scores across different content types (Movies vs. TV Shows). This chart is superior to averages because it shows the "spread" of the data, including the median, the range where most scores fall (the box), and the outliers (dots). This helps me answer not just "which is higher?" but also "which is more consistent?".

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **TV Shows are Rated Higher:** The median score (the line inside the box) for TV Shows is noticeably higher (7.2) than for Movies (6.0). This indicates that, on average, users rate TV series more favorably than films.
#
# **Movies have a Wider Spread:** The box for Movies is taller and the whiskers are longer, meaning the quality of movies varies wildly—from terrible (scores near 1) to excellent. TV shows are more consistently "good."
#
# **Outliers:** Both categories have outliers (the small circles), particularly on the low end. This means there are some really bad movies and shows that fall far below the standard quality range.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Investment** :- Since TV Shows generally achieve higher customer satisfaction scores, increasing the budget for original series (like The Boys or Reacher) is a safer bet for maintaining a high-quality reputation than churning out many average movies.
#
# **Quality Control** :- The wide variation in Movie ratings suggests a need for stricter quality control. The business might want to be more selective in acquiring films to raise the "floor" of the library's quality, avoiding those low-rated outliers that dilute the brand.

# %% [markdown]
# #### Chart - 6--(Horizontal)Bar Chart-----(Top 10 Bankable Actors)

# %%
# Chart - 6 visualization code

# Merged datasets (Safety check to ensure we have the combined data)
# joining 'Amazon_titles' with 'Amazon_credits' on the 'id' column
df_merged = pd.merge(titles,credits, on='id', how='inner')

# Filter for ACTORS only
actor_stats = df_merged[df_merged['role'] == 'ACTOR']

# Group by Actor Name and calculated Average Rating & Count
# Wanted to know the Mean Score and How Many titles they did
actor_metrics = actor_stats.groupby('name')['imdb_score'].agg(['mean', 'count'])

# Filtering established actors (at least 5 titles)
# This removes actors who appeared in only 1 movie that happened to get a 10/10.
established_actors = actor_metrics[actor_metrics['count'] >= 5]

# Sorted by Highest Average Score and taken Top 10
top_quality_actors = established_actors.sort_values(by='mean', ascending=False).head(10)

# Visualization of chart
plt.figure(figsize=(12, 6))

# Creating Horizontal Bar Plot
ax = sns.barplot(x=top_quality_actors['mean'], y=top_quality_actors.index, palette='plasma')

# Added title and labels
plt.title('Top 10 "Bankable" Actors (Highest Avg IMDb Score, Min 5 Titles)', fontsize=16)
plt.xlabel('Average IMDb Score', fontsize=12)
plt.ylabel('Actor Name', fontsize=12)
plt.xlim(7, 10) # Zoom in on the high scores (7-10) to see differences clearly

# Added numbers to bars
for container in ax.containers:
    ax.bar_label(container, fmt='%.1f', padding=3)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart allows the business to identify "Bankable Talent"—actors whose presence guarantees a high-quality production.By filtering for actors with at least 5 titles, I ensured that the list represents "consistent performers" rather than "one-hit wonders."

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **South Indian Cinema Dominance:** The #1 spot is held by 'Poo' Ram (8.4), a critically acclaimed Tamil actor. Other Indian actors like Fahadh Faasil (7.8) and Ajay Ghosh (7.8) also appear. This proves that Indian regional cinema (Tamil, Malayalam, Telugu) drives some of the highest user satisfaction ratings on the entire platform.
#
# **No Hollywood A-Listers**: There is a complete absence of mainstream American stars. This suggests that while Hollywood stars bring volume (Chart 7), niche regional and animated actors bring quality.
#
# **The Anime Factor:** Almost half the list consists of legendary Japanese voice actors like Hiroaki Hirata (7.9), Mamiko Noto (7.8), and Akio Otsuka (7.7). This indicates that the Anime category on Amazon Prime is consistently rated excellent (likely 8.0+) compared to live-action movies.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Higher Subscriber Growth in Indian Market :**
# Featuring popular South actors helps attract and retain Indian subscribers, especially from South India, one of the fastest-growing OTT markets.
#
# **Stronger Engagement & Watch Time :**
# Fans of these actors are more likely to binge-watch their movies and shows, leading to:
#
# Increased session duration
#
# Better retention rates
#
# **Higher recommendation algorithm performance :**
#
# Localization Strategy Success
# This proves that the platform’s regional content investment strategy is working, reducing dependence on only Hollywood or Bollywood.

# %% [markdown]
# #### Chart 7 ---(Bar Chart)---Top 10 Actors Name By titles.

# %%
# Chart - 7 visualization code

# Merging Dataset
# We need to join Titles and Credits Dataset to connect 'Movies' with 'Actors'
# We use an 'inner' join on the 'id' column.
df_merged = pd.merge(titles,credits, on ='id', how = 'inner')

# Preparing Dataset Filtering Only 'ACTOR'
actors_df = df_merged[df_merged['role'] == 'ACTOR']

# the top 10 Actors by number of titles they appear in
top_actors = actors_df['name'].value_counts().head(10)

# Visualization Of top 10 Actor Using Bar Plot
plt.figure(figsize=(12,6))

# Creating Horizontal Bar plot
ax = sns.barplot(x=top_actors.values, y=top_actors.index, palette='magma')

# Adding Title and labels
plt.title('Top 10 Actors on Amazon Prime Video', fontsize=16)
plt.xlabel('Number of Titles', fontsize=12)
plt.ylabel('Actor Name', fontsize=12)

# Adding numbers to the end of bars
for container in ax.containers:
    ax.bar_label(container, padding=3)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I needed to rank people (Actors) by how many movies they have been in. Since actor names are long, a horizontal chart makes it much easier to read than a vertical one. This chart helps me identify which actors appear most frequently across the entire platform.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **The leading actors** — George “Gabby” Hayes (49 titles), Roy Rogers (45), and Gene Autry (40) — are well-known legends of the American Western film era from the 1930s to the 1950s. Their dominance in the dataset indicates that Amazon Prime holds a very large collection of classic Western movies, highlighting a strong focus on vintage Hollywood content.
#
# **Actors** such as Bess Flowers (44) and Herman Hack (35) were famous as highly active supporting or background performers who appeared in a huge number of films. Their high frequency in the data reflects the rich depth of classic Hollywood cinema available on the platform, especially from earlier decades.
#
# The **inclusion** of Nassar (37), a respected veteran actor from South Indian cinema, once again confirms the platform’s strong linkage with the Indian market. This aligns with earlier country-level insights (Chart 4) and shows that Amazon Prime is actively investing in or acquiring content that appeals to Indian audiences.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive:**
# Low-Cost, High-Volume Content Strategy
# The dominance of classic Western actors (e.g., George “Gabby” Hayes, Roy Rogers, Gene Autry) suggests that Amazon Prime is leveraging public-domain or low-licensing-cost content. This allows the platform to expand its content library at minimal cost while still offering genre diversity.
#
# Niche Audience Retention through Classic Cinema
# A strong catalog of vintage Hollywood films helps retain niche user segments, such as older viewers and classic movie enthusiasts. This supports long-term engagement without heavy investment in new productions.
#
# Strong Localization for the Indian Market
# The presence of Nassar, a leading South Indian actor, reinforces Amazon Prime’s localization strategy. Investing in regional Indian content drives subscriber growth and engagement in one of the world’s fastest-growing OTT markets.
#
#
# **Negative:**
# Content Perception Risk
# A large volume of older films may create a perception that the platform prioritizes quantity over freshness, potentially weakening brand positioning against competitors with newer originals.
#
# Talent Concentration Risk (India)
# Dependence on a few popular regional actors could lead to rising acquisition costs or scheduling risks if future collaborations become expensive or limited.

# %% [markdown]
# #### Chart - 8---(Bar Chart)---Top 10 Directors NUmber by title

# %%
# Chart - 8 visualization code
# Preparing Dataset Filtering Dataset df_merged for 'DIRECTOR'
directors_df = df_merged[df_merged['role'] == 'DIRECTOR']

# the top 10 Actors by number of titles they appear in
top_directors = directors_df['name'].value_counts().head(10)

# Visualization Of top 10 Directors Using Bar Plot
plt.figure(figsize=(12,6))

# Creating Horizontal Bar plot
ax = sns.barplot(x=top_directors.values, y=top_directors.index, palette='crest')

# Adding Title and labels
plt.title('Top 10 Directors on Amazon Prime Video', fontsize=16)
plt.xlabel('Number of Titles', fontsize=12)
plt.ylabel('Directors Name', fontsize=12)

# Adding numbers to the end of bars
for container in ax.containers:
    ax.bar_label(container, padding=3)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Just like with the Actors, listing the names horizontally is the cleanest way to display this categorical data. This chart helps identify the key creative figures responsible for the highest volume of content on the platform.I chose a Horizontal Bar Chart to visualize the most prolific directors.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The dominance of directors like Joseph Kane (41) and Sam Newfield (38)—known for low-budget B-Westerns—indicates that the platform is using a high-volume, low-cost acquisition model. Classic genre films are inexpensive to license and help rapidly scale the content library without heavy production spending.
#
#
# The repeated appearance of Western-focused directors such as Lesley Selander (22) confirms a strategic niche dominance in the Western genre. This helps Amazon Prime differentiate itself from competitors by catering to loyal fans of classic Western cinema.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The top-director analysis highlights a cost-efficient, high-volume content strategy built around classic Western cinema, driven by prolific low-budget directors like Joseph Kane, Sam Newfield, and Lesley Selander. This niche dominance helps retain loyal genre audiences while keeping licensing costs low. At the same time, the presence of Jay Chapman reflects a strategic expansion into stand-up comedy, aligning with the platform’s strong performance in the Comedy genre. While this diversified approach supports engagement and growth, over-reliance on older Western content may limit appeal among younger and international viewers, indicating the need for a balanced mix of modern originals and global genres.

# %% [markdown]
# #### Chart - 9---(Histogram)------The Runtime Distribution--

# %%
# Chart - 9 visualization code

# Filtering extreme outliers for a cleaner chart
# We keep titles under 200 minutes (3+ hours) to focus on the main content library.
df_filtered = titles[titles['runtime'] < 200]

# Visualization
plt.figure(figsize=(12, 6))

# Creating a Histogram with KDE (Kernel Density Estimate)
# Adding hue='type'
sns.histplot(
    data=df_filtered,
    x='runtime',
    hue='type',
    kde=True,
    bins=30,
    palette='viridis',
    element='step'
)

# Adding title and labels
plt.title('Distribution of Duration: Movies vs. TV Shows', fontsize=16)
plt.xlabel('Runtime (Minutes)', fontsize=12)
plt.ylabel('Number of Titles', fontsize=12)

# Adding reference lines for standard lengths
plt.axvline(x=22, color='orange', linestyle='--', label='TV Show Standard (22m)')
plt.axvline(x=90, color='red', linestyle='--', label='Movie Standard (90m)')

plt.legend()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Histogram with KDE to visualize the distribution of content duration. Since "Movies" and "TV Shows" have vastly different standard lengths, plotting them together with different colors allows me to clearly see the two distinct clusters (short-form vs. long-form) and identify the most common runtime for each type.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The two clear peaks—20–45 minutes for TV shows and 90–100 minutes for movies—show that Amazon Prime aligns its content library with standard industry runtimes. This helps match natural user viewing patterns, increasing the likelihood of content being completed in a single session and improving user satisfaction.
#
# The presence of 45–60 minute movies (likely documentaries, stand-up specials, or animated films) reflects a hybrid content strategy. These formats serve users who want movie-like content but have limited time, filling an important gap between full-length films and TV episodes.
#
# **Potential Risks**
#
# User Confusion from Short Movies
# Movies under 60 minutes may confuse users expecting full-length films, potentially leading to negative user experience or lower ratings if expectations are not managed properly.
#
# Perceived Inconsistency in Content Labeling
# Classifying short documentaries or stand-up specials as “Movies” could weaken content discoverability and trust in platform categorization.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The duration analysis reveals a well-structured content strategy, with TV shows concentrated around 20–45 minutes and movies peaking at 90–100 minutes, aligning with standard industry formats and viewer behavior. This supports binge-watching, improves session completion rates, and enhances recommendation accuracy. The presence of short movies (45–60 minutes) highlights a flexible programming approach that caters to time-constrained users through documentaries and stand-up specials

# %% [markdown]
# #### Chart - 10----(Pie Chart)-----Age Certification

# %%
# Chart - 10 visualization code
# Count the values for each age ratings.

rated_content = titles[titles['age_certification'] != 'Not Rated'] # Filtering Out 'Not Rated' Movies & TV Shows.

# I will take Top 5 ratings to Maintain Pie Chart clean
rating_counts = rated_content['age_certification'].value_counts().head(5)

# Implementing visualization for Pie chart
plt.figure(figsize=(10,8))

# Creating Pie Chart
plt.pie(
    rating_counts.values,
    labels=rating_counts.index,
    autopct='%1.1f%%',       # Show percentages with 1 decimal place
    startangle=140,          # Rotate start for better look
    colors=sns.color_palette('pastel'), # Use pastel colors
    explode=(0.02, 0, 0, 0, 0) # Explode the first slice slightly to highlight it
)

# Adding title
plt.title('Distribution of Age Certifications (Rated Content Only)', fontsize=16)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I take Pie Chart to analyze the composition of the platform's rated content. I specifically excluded the "Not Rated" category (which dominated the data) to "zoom in" on the known age ratings.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Core Market** = Teens + Adults (63% of Catalog)
# With PG-13 (20.2%) + R (43%) = 63%, the platform is clearly optimized for teen and adult demographics. This aligns well with high-demand genres like drama, comedy, thriller, and action, which also appeared at the top in your genre analysis.
#
# **Lower Priority**  on Kids & Family Content
# The combined share of PG (20%) and G (9.3%), totaling under 30%, indicates that family-friendly content is a secondary focus. This suggests Amazon Prime is positioning itself more as an adult entertainment platform rather than a child-centric service like Disney+.
#
# **Limited Appeal to Families with Young Children**
# A smaller family-friendly catalog may reduce household subscriptions, where multiple age groups influence platform choice.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The age certification analysis reveals that Amazon Prime is heavily focused on mature audiences, with R-rated content alone accounting for 43% of the catalog and over 63% targeting teens and adults (PG-13 + R). This supports a premium, adult-oriented brand positioning and higher monetization potential through high-engagement genres like drama, thriller, and action. However, the relatively small share of family-friendly content (under 30%) limits appeal to households with children and represents a missed growth opportunity, suggesting the need for a more balanced content mix to improve long-term subscriber retention.

# %% [markdown]
# #### Chart - 11-----(Line Plot)----Imdb score over time(2000-2021)

# %%
# Chart - 11 visualization code

# Filter data for the modern era (2000 onwards).
# Focusing on recent history where the volume of content is significant.
df_trend = titles[titles['release_year'] >= 2000]
plt.figure(figsize=(12, 6)) # Setting up fig size

# Creating a Line Plot
# This automatically calculates the mean rating per year and plots it.
# The shaded area around the line is the "Confidence Interval" (variation).
sns.lineplot(
    data=df_trend,
    x='release_year',
    y='imdb_score',
    hue='type',         # Compare Movies (Blue) vs TV Shows (Orange)
    palette='tab10',    # Distinct colors
    marker='o'          # Added dots to make data points clear
)

# Adding title and labels
plt.title('Trend of Average IMDb Scores Over Time (2000 - Present)', fontsize=16)
plt.xlabel('Release Year', fontsize=12)
plt.ylabel('Average IMDb Score', fontsize=12)

# Add a horizontal line for the overall average (5.25)
plt.axhline(y=5.25, color='gray', linestyle='--', label='Platform Average (5.25)')
plt.legend()

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I take a Line Plot with Confidence Intervals because it is the standard and most effective way to visualize trends over time (Time Series Analysis). By plotting the average IMDb score year-by-year, I can instantly see if the quality of content is trending upwards, downwards, or staying flat.Separating Movies and TV Shows (using different colors) allows me to compare their individual performance, while the shaded confidence intervals show the variability of ratings in each year.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# TV Shows Are the Primary Quality Driver
# Since TV shows consistently outperform movies in average ratings across the entire 20-year period, this indicates that serialized content is Amazon Prime’s strongest content pillar. High-quality series drive:
#
# *Higher user satisfaction*
#
# *Longer watch time*
# *Better subscriber retention*
#
# *This validates a strategy of prioritizing original series and episodic content over standalone films.*
#
# Weak Performance in Movies
# The flat and below-average movie ratings suggest that the movie library lacks consistent quality. This likely results from:
#
# Heavy acquisition of low-budget or filler content
#
# A volume-driven strategy rather than quality-driven

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The ratings trend analysis shows that TV shows consistently outperform movies in user satisfaction, confirming serialized content as Amazon Prime’s strongest growth and retention driver. In contrast, movie ratings remain stagnant and below average, likely due to a volume-heavy acquisition strategy focused on low-budget and filler content. The volatility in TV show ratings highlights a hit-driven model, where a few flagship series significantly impact platform performance. The sharp decline in ratings during 2020–2022 reflects pandemic-era production challenges and a temporary shift from quality to quantity. Together, these trends indicate a strategic need for Amazon Prime to rebalance toward fewer, higher-quality films and sustained investment in premium original series.

# %% [markdown]
# #### Chart - 12--(Box Plot)--Age rating Impact

# %%
# Chart - 12 visualization code

# Filtered the dataset for the most common Age Ratings to keep the chart clean
# selecting the standard MPAA and TV guidelines.
target_ratings = ['G', 'PG', 'PG-13', 'R', 'TV-G', 'TV-PG', 'TV-14', 'TV-MA']
df_age_quality = titles[titles['age_certification'].isin(target_ratings)]

# Visualization of Box Plot
plt.figure(figsize=(14, 7))

# This shows the median quality and range for each age group.
sns.boxplot(
    data=df_age_quality,
    x='age_certification',
    y='imdb_score',
    order=target_ratings, # Ordering them from "Young" to "Mature"
    palette='coolwarm'
)

# Added title and labels
plt.title('Impact of Age Rating on Quality (IMDb Score)', fontsize=16)
plt.xlabel('Age Certification', fontsize=12)
plt.ylabel('IMDb Score', fontsize=12)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Box Plot because it allows me to compare the "quality spread" across different age groups. Instead of just looking at the average, the box plot shows the median (the middle line) and the consistency (the size of the box).This answer the business question: "Is producing mature content actually safer or riskier than family content?".

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **TV Content Clearly Outperforms Movies**
# All TV categories (TV-MA, TV-14, TV-PG) show noticeably higher median ratings than movie categories (R, PG-13, PG, G). This indicates that users consistently rate Amazon Prime’s series content as higher quality than its film library.
#
# **TV-MA Delivers the Strongest Viewer Satisfaction**
# The TV-MA category records the highest median score (around 7.5), showing that mature, story-driven series generate the most positive audience response. This suggests strong viewer preference for complex, adult-oriented storytelling.
#
# **Movies Underperform on Perceived Quality**
# Movie ratings cluster around a lower median (~6.0), implying that while the platform offers a large number of films, their overall quality perception is weaker compared to TV shows.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Greenlight Strategy:** The data strongly supports increasing the budget for TV-MA Originals. Shows like The Boys or Invincible aren't just popular; they are the highest-quality assets the platform has.
#
# **Movie Acquisition Reform:** The low median scores for R and PG-13 movies suggest a "quantity over quality" issue. The content team needs to implement stricter quality filters for acquiring movies, as the current library is weighed down by average content.
#
# **Family Strategy:** If the business wants to target families, they should invest in TV-PG series rather than PG movies, as the series format consistently delivers higher user satisfaction in that demographic.

# %% [markdown]
# #### Chart - 13 IMDb Votes vs. IMDb Score Using Bouble (Scatter Plot)

# %%
# Chart - 13 visualization code

# Filtering data to remove titles with 0 scores or votes
df_bubble = titles[
    (titles['imdb_score'] > 0) &
    (titles['tmdb_score'] > 0) &
    (titles['imdb_votes'] > 0)
]

# Create Interactive Bubble Plot
fig = px.scatter(
    df_bubble,
    x='imdb_score',
    y='tmdb_score',
    size='imdb_votes',     # Bubble size depends on popularity
    color='type',          # Color by Movie vs Show
    hover_name='title',    # SHOWS TITLE ON HOVER (Key Feature!)
    hover_data=['release_year'], # Add extra info to hover
    size_max=60,           # limit max bubble size
    opacity=0.6,
    template='plotly_white',
    title='<b>Interactive Correlation: IMDb vs TMDB Scores</b><br>(Size = Popularity)',
    labels={'imdb_score': 'IMDb Score', 'tmdb_score': 'TMDB Score'}
)

# Added a diagonal line for reference
fig.add_shape(
    type="line",
    x0=0, y0=0, x1=10, y1=10,
    line=dict(color="Red", width=2, dash="dash")
)

fig.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bubble Plot because it is the most effective way to visualize a Multivariate Analysis involving three key variables simultaneously:
#
# *X-Axis: IMDb Score (Quality Metric A)*
#
# *Y-Axis: TMDB Score (Quality Metric B)*
#
# This visualization allows us to validate the reliability of quality metrics (do the platforms agree?) while simultaneously seeing if "High Quality" content correlates with "High Popularity" (big bubbles). It directly addresses the business objective of understanding the relationship between Content Quality and User Engagement.
# *Bubble Size: IMDb Votes (Engagement/Popularity)**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Strong Agreement Between Rating Platforms**
# The tight clustering of points along the diagonal shows a high correlation between IMDb and TMDB scores, meaning both platforms largely agree on content quality. High-rated titles on one platform are almost always high-rated on the other.
#
# **High Quality Drives High Popularity**
# The largest bubbles (most voted titles) are mostly located in the upper-right quadrant (scores above 7.0). This confirms that content with better ratings also receives higher audience engagement and visibility.
#
# **Large Volume of Low-Impact Movies**
# A dense concentration of small movie bubbles appears in the lower-left quadrant (below 6.0), indicating many low-rated and low-popularity films. These titles contribute little to user engagement and mainly increase catalog size.
#
# **TV Shows Consistently Outperform Movies**
# TV shows are more heavily clustered in the high-score region than movies, reinforcing the insight that serialized content is perceived as higher quality than Amazon Prime’s movie library.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Use Ratings as a Reliable Content Filter**
# Since IMDb and TMDB ratings closely align, Amazon Prime can confidently use external ratings as a quality benchmark for content acquisition, reducing the risk of licensing poor-performing titles.
#
# **Prioritize High-Quality, High-Engagement Content**
# The clear link between popularity and quality suggests that investing in fewer but higher-rated originals will deliver better returns in terms of watch time, retention, and brand perception.
#
# **Clean Up the Low-Value Content Pool**
# The large volume of low-rated, low-engagement movies indicates an opportunity to remove, deprioritize, or reclassify filler content to improve recommendation quality and overall user experience.
#
# **Double Down on Premium TV Content**
# The superior performance of TV shows in the high-rating zone supports increased investment in prestige series, which act as major subscriber growth and retention drivers.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap Visualization code
# Selecting only the numerical columns for correlation
# We exclude 'id', 'title', 'type', etc.
numeric_df = titles.select_dtypes(include=['float64', 'int64'])

# Calculate the correlation matrix
# This gives us a number between -1 and 1 for every pair of variables
corr_matrix = numeric_df.corr()

# Creating the Heatmap
plt.figure(figsize=(12, 8))

# sns.heatmap arguments:
# annot=True: for Writing the correlation number on each box
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)

# Adding title
plt.title('Correlation Heatmap of Numeric Variables', fontsize=16)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Correlation Heatmap because I wanted to see how all the numerical variables (like release year, scores, and popularity) relate to each other in one single view.
#
# This chart uses color to show the strength of relationships, making it easy to spot if two things (like IMDb Score and TMDB Score) move together or if they have no connection at all.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Most Variables Show Weak Relationships**
# The majority of correlation values are close to zero, indicating that most features (such as runtime, scores, and popularity) do not strongly influence one another. For example, longer content does not necessarily receive higher IMDb ratings, proving that duration is not a quality indicator.
#
# **Popularity and Votes Are Closely Linked**
# The strongest positive relationship appears between IMDb votes and TMDB popularity (≈ 0.25). This suggests that titles people actively rate on IMDb are also the ones gaining higher visibility and search interest on TMDB, reflecting a shared measure of audience attention.
#
# **Seasons vs Runtime Show an Inverse Relationship**
# There is a clear negative correlation (≈ -0.32) between number of seasons and runtime, which aligns with content structure. Movies typically have longer runtimes but zero seasons, while TV shows have multiple seasons but shorter episode lengths.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Chart - 15 visualization code

# Defining the columns we want to plot
cols_to_plot = ['release_year', 'imdb_score', 'tmdb_score', 'tmdb_popularity']

# Filtering the data to remove 0 values
# created a temporary dataframe 'df_pair' that only contains rows where scores and popularity are greater than 0.
df_pair = titles[
    (titles['imdb_score'] > 0) &
    (titles['tmdb_score'] > 0) &
    (titles['tmdb_popularity'] > 0)
]

# Create Pair Plot
sns.pairplot(
    data=df_pair,
    vars=cols_to_plot,
    hue='type',       # Colors by Movie vs TV Show
    palette='husl',
    height=2.5,
    plot_kws={'alpha': 0.5} # Transparency to see overlaps
)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# In Final Visualization I take pair plot because It automatically creates a grid of scatter plots for every combination of numerical variables (release_year, scores, popularity) while simultaneously showing their individual distributions on the diagonal. This allows me to spot any remaining patterns, clusters, or outliers across the entire dataset in a single view.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Rapid Content Expansion in Recent Years
# The release year distribution shows a sharp rise in titles between 2015 and 2021, confirming that Amazon Prime has scaled its content library aggressively in the last decade. This reflects a strategic push to compete with other OTT platforms through volume growth.
#
# Strong Agreement Between IMDb and TMDB Scores
# The close, diagonal pattern in the IMDb vs TMDB scatter plot indicates a high consistency in quality ratings across both platforms. If a title is rated well on one site, it is very likely rated well on the other.
#
# Popularity Is Highly Skewed Toward a Few Hits
# The popularity-related scatter plots show that a small number of titles dominate user attention, while most content receives very low popularity, regardless of rating. This highlights a classic “hit-driven” consumption pattern.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# 1. **Prioritize Premium TV Content (Especially TV-MA)**
#
# **Insight:**
# The analysis shows that TV shows consistently receive higher user ratings than movies (median ~7.2 vs ~6.0). Among all categories, TV-MA content performs the best, indicating strong audience preference for mature, story-driven series.
#
# **Business Action:**
# Shift budget away from bulk movie acquisitions and invest more in adult-oriented original series (Drama, Thriller, Action). These formats deliver stronger engagement, longer watch time, and better subscriber retention.
#
# 2. **Use Regional Content as a Global Growth Engine (India Focus)**
#
# **Insight:**
# India ranks as the second-largest content producer on the platform, and Indian actors/directors frequently appear among top-rated talent. This confirms strong demand and performance for regional Indian content.
#
# **Business Action:**
# Increase investment in high-quality regional originals (Tamil, Telugu, Hindi). Leverage this strength to expand dominance across the South Asian OTT market and attract international audiences interested in global cinema.
#
# 3. **Promote “Hidden Gems” Through Smarter Recommendations**
#
# **Insight:**
# The bubble plot highlights many titles with high IMDb scores (>7.0) but low vote counts, meaning quality content exists but remains under-discovered.
#
# **Business Action:**
# Upgrade the recommendation system to surface these high-rated, low-visibility titles more frequently. This can boost watch time and user satisfaction without increasing content acquisition costs.
#
# 4. **Set a Minimum Quality Standard for Movies**
#
# **Insight:**
# The movie library shows signs of quality dilution, with a large number of average or low-rated titles reducing overall brand value.
#
# **Business Action:**
# Stop renewing licenses for movies with IMDb scores below 5.0 unless they show strong viewership. Redirect film investment toward high-performing niches like Anime and Documentaries, which consistently receive better audience response.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# 1. **Content Mix Imbalance:**
# Although movies make up the majority of the catalog (around 78%), they perform noticeably worse than TV shows in terms of user ratings. The strongest performers on the platform are serialized formats, especially TV-MA originals and Anime, which consistently achieve higher IMDb scores and stronger audience approval.
#
# 2. **Regional Content as a Growth Engine:**
# India has become a major content contributor, ranking second globally in production volume. In addition, regional creators from India and Japan (particularly in Anime) frequently outperform traditional Hollywood talent when measured by average content quality, showing the rising power of non-Western entertainment markets.
#
# 3. **Untapped Value in Under-Discovered Titles:**
# A large section of the library consists of high-quality but low-visibility content. These “hidden gems” represent an overlooked opportunity to boost engagement and watch time without increasing content acquisition costs.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
